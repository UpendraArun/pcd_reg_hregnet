# %% [markdown]
# # Plot Distributions

# %%
import sys
sys.path.append('/workspace/')

import json
import numpy as np

from visualize.visualize_results import VisaulizeResults, VisualizeResults

# %% [markdown]
# # Plot Perturbations - Baseline

# %%
# Load JSON file
with open("/workspace/results/Baseline_Hregnet/results.json", "r") as file:
    data_dict = json.load(file)

viz = VisualizeResults()

viz.plot_perturbation(np.asarray(data_dict['layer_2']['pred_calib']),np.asarray(data_dict['layer_2']['error_calib']) )

# %% [markdown]
# # A2

# %%
# Load JSON file
with open("/workspace/results/Adaption2_ptv3/results_v1.json", "r") as file:
    data_dict = json.load(file)

viz = VisualizeResults()

viz.plot_perturbation(np.asarray(data_dict['layer_2']['pred_calib']),np.asarray(data_dict['layer_2']['error_calib']) )
